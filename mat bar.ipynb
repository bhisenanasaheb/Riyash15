# %%
import matplotlib.pyplot as plt
# %matplotlib inline
import numpy as np

# %%
company = ["google","amzn","msft","fb"]
revenue = [95,89,75,78]
profit = [30,20,45,15]

# %%
ypos = np.arange(len(company))
plt.xticks(ypos,company) # ticks for use for giving number 
plt.bar(ypos,revenue)
plt.bar(ypos,profit)
#plt.xlabel("stock")
#plt.ylabel("revenue")
#plt.title("my stock")
#plt.legend()
# Out:
# <BarContainer object of 4 artists>
