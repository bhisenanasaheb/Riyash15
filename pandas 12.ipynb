# %%
import pandas as pd 
import numpy as np
import matplotlib.pyplot as plt

# %%
 ipl=pd.read_csv("../data.csv")

# %%
ipl.head(2)
# Out:
#    id  season        city        date                  team1  \
# 0   1    2008   Bangalore  18-04-2008  Kolkata Knight Riders
# 1   2    2008  Chandigarh  19-04-2008    Chennai Super Kings
#
#                          team2                  toss_winner toss_decision  \
# 0  Royal Challengers Bangalore  Royal Challengers Bangalore         field
# 1              Kings XI Punjab          Chennai Super Kings           bat
#
#    result  dl_applied                 winner  win_by_runs  win_by_wickets  \
# 0  normal           0  Kolkata Knight Riders          140               0
# 1  normal           0    Chennai Super Kings           33               0
#
#   player_of_match                                       venue    umpire1  \
# 0     BB McCullum                       M Chinnaswamy Stadium  Asad Rauf
# 1      MEK Hussey  Punjab Cricket Association Stadium, Mohali  MR Benson
#
#        umpire2  umpire3
# 0  RE Koertzen      NaN
# 1   SL Shastri      NaN

# %%
 data1=  ipl[["season","city","winner","venue"]]

# %%
data1.shape
# Out:
# (577, 4)

# %%
data1.iloc[-10:,[1,2,3]]
# Out:
#               city                       winner  \
# 567         Kanpur                Gujarat Lions
# 568         Raipur             Delhi Daredevils
# 569  Visakhapatnam      Rising Pune Supergiants
# 570         Kanpur                Gujarat Lions
# 571        Kolkata        Kolkata Knight Riders
# 572         Raipur  Royal Challengers Bangalore
# 573      Bangalore  Royal Challengers Bangalore
# 574          Delhi          Sunrisers Hyderabad
# 575          Delhi          Sunrisers Hyderabad
# 576      Bangalore          Sunrisers Hyderabad
#
#                                                  venue
# 567                                         Green Park
# 568   Shaheed Veer Narayan Singh International Stadium
# 569  Dr. Y.S. Rajasekhara Reddy ACA-VDCA Cricket St...
# 570                                         Green Park
# 571                                       Eden Gardens
# 572   Shaheed Veer Narayan Singh International Stadium
# ...

# %%
win=data1["winner"]=="Gujarat Lions"
data1[win]
# Out:
#      season        city         winner  \
# 519    2016  Chandigarh  Gujarat Lions
# 522    2016      Rajkot  Gujarat Lions
# 525    2016      Mumbai  Gujarat Lions
# 535    2016      Rajkot  Gujarat Lions
# 539    2016       Delhi  Gujarat Lions
# 541    2016        Pune  Gujarat Lions
# 554    2016     Kolkata  Gujarat Lions
# 567    2016      Kanpur  Gujarat Lions
# 570    2016      Kanpur  Gujarat Lions
#
#                                                  venue
# 519  Punjab Cricket Association IS Bindra Stadium, ...
# 522             Saurashtra Cricket Association Stadium
# 525                                   Wankhede Stadium
# 535             Saurashtra Cricket Association Stadium
# 539                                   Feroz Shah Kotla
# 541            Maharashtra Cricket Association Stadium
# 554                                       Eden Gardens
# 567                                         Green Park
# 570                                         Green Park

# %%
def winner_of_the_match(winner):
    win=data1["winner"]== winner
    return data1[win]

# %%
winner_of_the_match("Royal Challengers Bangalore").shape
# Out:
# (70, 4)

# %%
place=data1['city']=='Pune'
data1[place]
# Out:
#      season  city                       winner  \
# 255    2012  Pune                Pune Warriors
# 264    2012  Pune                Pune Warriors
# 279    2012  Pune             Delhi Daredevils
# 281    2012  Pune              Deccan Chargers
# 291    2012  Pune               Mumbai Indians
# 298    2012  Pune             Rajasthan Royals
# 302    2012  Pune  Royal Challengers Bangalore
# 315    2012  Pune        Kolkata Knight Riders
# 318    2012  Pune        Kolkata Knight Riders
# 327    2013  Pune              Kings XI Punjab
# 333    2013  Pune                Pune Warriors
# 342    2013  Pune          Sunrisers Hyderabad
# 362    2013  Pune          Chennai Super Kings
# 366    2013  Pune  Royal Challengers Bangalore
# 377    2013  Pune        Kolkata Knight Riders
# 379    2013  Pune               Mumbai Indians
# 391    2013  Pune                Pune Warriors
# 460    2015  Pune             Rajasthan Royals
# 468    2015  Pune             Delhi Daredevils
# ...

# %%
sea=data1["season"]==2014
data1[sea]
# Out:
#      season        city                       winner  \
# 398    2014   Abu Dhabi        Kolkata Knight Riders
# 399    2014     Sharjah  Royal Challengers Bangalore
# 400    2014   Abu Dhabi              Kings XI Punjab
# 401    2014   Abu Dhabi             Rajasthan Royals
# 402    2014         NaN  Royal Challengers Bangalore
# 403    2014         NaN             Delhi Daredevils
# 404    2014     Sharjah              Kings XI Punjab
# 405    2014   Abu Dhabi          Chennai Super Kings
# 406    2014     Sharjah              Kings XI Punjab
# 407    2014         NaN          Chennai Super Kings
# 408    2014     Sharjah        Kolkata Knight Riders
# 409    2014         NaN          Sunrisers Hyderabad
# 410    2014         NaN          Chennai Super Kings
# 411    2014   Abu Dhabi             Rajasthan Royals
# 412    2014   Abu Dhabi              Kings XI Punjab
# 413    2014     Sharjah             Delhi Daredevils
# 414    2014     Sharjah          Chennai Super Kings
# ...

# %%
def winner_of_city(city,winner,season):
    place=data1["city"]==city
    win=data1["winner"]== winner
    sea=data1["season"]> season
    return data1[place & win &sea]

# %%
winner_of_city('Abu Dhabi','Rajasthan Royals',2010)
# Out:
#      season       city            winner                 venue
# 401    2014  Abu Dhabi  Rajasthan Royals  Sheikh Zayed Stadium
# 411    2014  Abu Dhabi  Rajasthan Royals  Sheikh Zayed Stadium
# 416    2014  Abu Dhabi  Rajasthan Royals  Sheikh Zayed Stadium

# %%
data1['city'].value_counts()
# Out:
# city
# Mumbai            77
# Bangalore         58
# Kolkata           54
# Delhi             53
# Chennai           48
# Chandigarh        42
# Hyderabad         41
# Jaipur            33
# Pune              25
# Durban            15
# Ahmedabad         12
# Centurion         12
# Visakhapatnam     11
# Dharamsala         9
# Johannesburg       8
# Abu Dhabi          7
# Cape Town          7
# Port Elizabeth     7
# Cuttack            7
# Ranchi             7
# Sharjah            6
# Raipur             6
# Rajkot             5
# Kochi              5
# East London        3
# Nagpur             3
# Kimberley          3
# Bloemfontein       2
# Indore             2
# Kanpur             2
# Name: count, dtype: int64

# %%
sym=data1["city"]=='Kanpur'
data1[sym]
# Out:
#      season    city         winner       venue
# 567    2016  Kanpur  Gujarat Lions  Green Park
# 570    2016  Kanpur  Gujarat Lions  Green Park

# %%
data1["venue"].value_counts().sort_values('venue',ascending="false")
# Out:
# ---------------------------------------------------------------------------
# TypeError                                 Traceback (most recent call last)
# Cell In[168], line 1
# ----> 1 data1["venue"].value_counts().sort_values('venue',ascending="false")
#
# TypeError: Series.sort_values() takes 1 positional argument but 2 positional arguments (and 1 keyword-only argument) were given
